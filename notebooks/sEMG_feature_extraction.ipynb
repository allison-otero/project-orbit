# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

WINDOW_SIZE  = 200
NUM_CHANNELS = 1
CHANNELS     = ['voltage']
CLASS_NAMES  = ['squat', 'lunge', 'jump']

def load_gesture_file(filepath, label):
    """
    Each line in the file is one gesture window: 50 samples × 6 channels = 300 floats.
    Lines starting with # are comments from the Arduino sketch — skip them.
    Returns a list of (window_array, label) tuples.
    window_array shape: (WINDOW_SIZE, NUM_CHANNELS)
    """
    samples = []
    with open(filepath, 'r') as f:
        for line in f:
            line = line.strip()
            if not line or line.startswith('#'):
                continue
            values = [float(v) for v in line.split(',')]
            if len(values) == WINDOW_SIZE * NUM_CHANNELS:
                window = np.array(values).reshape(WINDOW_SIZE, NUM_CHANNELS)
                samples.append((window, label))
            else:
                print(f"  Skipped malformed row ({len(values)} values, expected {WINDOW_SIZE * NUM_CHANNELS})")
    return samples

squat_samples = load_gesture_file(r"C:\Users\allis\OneDrive\Documents\agentic-mote-python\squat_data.txt", label=0)
lunge_samples = load_gesture_file(r"C:\Users\allis\OneDrive\Documents\agentic-mote-python\lunge_data.txt", label=1)
jump_samples  = load_gesture_file(r"C:\Users\allis\OneDrive\Documents\agentic-mote-python\jump_data.txt",  label=2)

print(f"Squat windows loaded: {len(squat_samples)}")
print(f"Lunge windows loaded: {len(lunge_samples)}")
print(f"Jump windows loaded:  {len(jump_samples)}")
total = len(squat_samples) + len(lunge_samples) + len(jump_samples)
print(f"Total: {total} windows")
# Out:
# Squat windows loaded: 60
# Lunge windows loaded: 60
# Jump windows loaded:  60
# Total: 180 windows

# %%
fig, axes = plt.subplots(3, 1, figsize=(14, 9), sharex=True, sharey=True)

sample_sets = [(squat_samples, 'squat'), (lunge_samples, 'lunge'), (jump_samples, 'jump')]
emg_channels = [('voltage', 0)]

for row, (samples, class_name) in enumerate(sample_sets):
    window = samples[0][0]   # grab the first collected window of this class
    t_ms = np.arange(WINDOW_SIZE) * 10  # 10 ms per sample = 100 Hz
    axes[row].plot(t_ms, window[:, ch_idx], linewidth=1.5)
    axes[row].set_title(f"'{class_name}' — {ch_name}")
    axes[row].set_ylabel("Voltage (V)")
    axes[row].grid(True, alpha=0.4)
    if row == 2:
        axes[row].set_xlabel("Time (ms)")

plt.suptitle("First captured window per gesture class — MyoWare EMG Voltage", fontsize=12)
plt.tight_layout()
plt.show()

# %%
def extract_features(window):
    """
    Extract 4 statistical features from one EMG window.
    Input:  window — numpy array of shape (WINDOW_SIZE, NUM_CHANNELS)
    Output: 1D numpy array of length 4, in this order:
            [mean, std, rms, p2p]
    """
    features = []
    for ch in range(NUM_CHANNELS):
        data = window[:, ch]
        mean  = np.mean(data)
        std   = np.std(data)
        rms   = np.sqrt(np.mean(data ** 2))
        p2p   = np.max(data) - np.min(data)
        features.extend([mean, std, rms, p2p])
    return np.array(features)

# Build human-readable feature names for debugging
FEATURE_NAMES = []
for ch_name in CHANNELS:
    for stat in ['mean', 'std', 'rms', 'p2p']:
        FEATURE_NAMES.append(f"{ch_name}_{stat}")

print(f"Features per window: {len(FEATURE_NAMES)}")
# Out:
# Features per window: 4

# %%
all_samples = squat_samples + lunge_samples + jump_samples

X = np.array([extract_features(window) for window, _ in all_samples])
y = np.array([label for _, label in all_samples])

print(f"Feature matrix X: shape = {X.shape}")  # (180, 4) if you collected 60 windows per class
print(f"Label vector y:   shape = {y.shape}")   # (180,)
# Out:
# Feature matrix X: shape = (180, 4)
# Label vector y:   shape = (180,)

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 7))
feature_indices_to_plot = [0, 1, 2, 3]  # std and p2p of several channels

y = np.array(y)

for ax_plot, feat_idx in zip(axes.flat, feature_indices_to_plot):
    for class_label, class_name, color in [(0,'squat','steelblue'),
                                            (1,'lunge','tomato'),
                                            (2,'jump', 'seagreen')]:
        values = X[y == class_label, feat_idx]
        ax_plot.hist(values, bins=12, alpha=0.5, label=class_name, color=color)
    ax_plot.set_title(FEATURE_NAMES[feat_idx])
    ax_plot.set_xlabel("Feature value")
    ax_plot.set_ylabel("Count")
    ax_plot.legend(fontsize=8)
    ax_plot.grid(True, alpha=0.3)

plt.suptitle("Feature distributions per class — do they separate?", fontsize=12)
plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Split the unscaled feature matrix first.
X_train_raw, X_test_raw, y_train, y_test = train_test_split(
    X, y,
    test_size=0.20,       # hold back 20% for final evaluation
    random_state=42,      # fixed seed for reproducibility
    stratify=y            # preserve class proportions in both sets
)

# Learn normalization parameters from training data only.
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train_raw)

# Apply the training transformation to the untouched test data.
X_test = scaler.transform(X_test_raw)

print(f"Training set:  {X_train.shape[0]} windows")
print(f"Test set:      {X_test.shape[0]} windows")
print()
for i, name in enumerate(CLASS_NAMES):
    print(f"  {name}: {np.sum(y_train == i)} train / {np.sum(y_test == i)} test")

# Show the effect of scaling on one training feature.
feat_idx = 1  # ax_std
print(f"\nFeature: {FEATURE_NAMES[feat_idx]}")
print(f"  Before scaling — mean: {X_train_raw[:, feat_idx].mean():.4f}, "
      f"std: {X_train_raw[:, feat_idx].std():.4f}")
print(f"  After scaling  — mean: {X_train[:, feat_idx].mean():.4f}, "
      f"std: {X_train[:, feat_idx].std():.4f}")
# Out:
# Training set:  144 windows
# Test set:      36 windows
#
#   squat: 48 train / 12 test
#   lunge: 48 train / 12 test
#   jump: 48 train / 12 test
#
# Feature: voltage_std
#   Before scaling — mean: 0.5683, std: 0.1701
#   After scaling  — mean: 0.0000, std: 1.0000

# %%
print("\n--- TRAINING NORMALIZATION PARAMETERS ---")
print(f"Number of features: {len(scaler.mean_)}")
print()
print("FEATURE_MEAN =", [round(v, 6) for v in scaler.mean_])
print()
print("FEATURE_STD  =", [round(v, 6) for v in scaler.scale_])
# Out:
# --- TRAINING NORMALIZATION PARAMETERS ---
# Number of features: 4
#
# FEATURE_MEAN = [np.float64(0.816162), np.float64(0.568294), np.float64(1.004991), np.float64(2.449833)]
#
# FEATURE_STD  = [np.float64(0.259587), np.float64(0.170129), np.float64(0.274593), np.float64(0.7188)]

# %%
manual_normalized = (X_test_raw[0] - scaler.mean_) / scaler.scale_

print("Manual calculation matches scaler.transform():",
      np.allclose(manual_normalized, X_test[0]))
# Out:
# Manual calculation matches scaler.transform(): True

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
y_pred_knn = knn.predict(X_test)

print("=== KNN Baseline Results ===\n")
print(classification_report(y_test, y_pred_knn, target_names=CLASS_NAMES))
# Out:
# === KNN Baseline Results ===
#
#               precision    recall  f1-score   support
#
#        squat       1.00      0.92      0.96        12
#        lunge       1.00      1.00      1.00        12
#         jump       0.92      1.00      0.96        12
#
#     accuracy                           0.97        36
#    macro avg       0.97      0.97      0.97        36
# weighted avg       0.97      0.97      0.97        36

# %%
cm  = confusion_matrix(y_test, y_pred_knn)
disp = ConfusionMatrixDisplay(cm, display_labels=CLASS_NAMES)
fig, ax = plt.subplots(figsize=(6, 5))
disp.plot(ax=ax, colorbar=False, cmap='Blues')
ax.set_title("KNN Baseline — Confusion Matrix")
plt.tight_layout()
plt.show()

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

NUM_FEATURES = X_train.shape[1]   # 24
NUM_CLASSES  = len(CLASS_NAMES)   # 3

model = keras.Sequential([
    layers.Input(shape=(NUM_FEATURES,)),
    layers.Dense(16, activation='relu'),   # first hidden layer: 24×16 + 16 = 400 params
    layers.Dense(8,  activation='relu'),   # second hidden layer: 16×8 + 8 = 136 params
    layers.Dense(NUM_CLASSES, activation='softmax')  # output: 8×3 + 3 = 27 params
], name='gesture_classifier')

model.summary()
# Out:
# Model: "gesture_classifier"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 16)             │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 3)              │            27 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 243 (972.00 B)
#  Trainable params: 243 (972.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer='adam',                          # adaptive learning rate — generally works well out of the box
    loss='sparse_categorical_crossentropy',    # standard loss for integer class labels
    metrics=['accuracy']
)

history = model.fit(
    X_train, y_train,
    epochs=200,
    batch_size=16,               # update weights after every 16 samples
    validation_split=0.15,       # hold back 15% of training data to monitor overfitting
    verbose=1                    # print progress each epoch
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.1639 - loss: 1.2120 - val_accuracy: 0.2273 - val_loss: 1.1681
# Epoch 2/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.2295 - loss: 1.1606 - val_accuracy: 0.3182 - val_loss: 1.1287
# Epoch 3/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4426 - loss: 1.1011 - val_accuracy: 0.4091 - val_loss: 1.0887
# Epoch 4/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.4918 - loss: 1.0454 - val_accuracy: 0.4545 - val_loss: 1.0497
# Epoch 5/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5082 - loss: 0.9891 - val_accuracy: 0.5455 - val_loss: 1.0133
# Epoch 6/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6230 - loss: 0.9340 - val_accuracy: 0.6818 - val_loss: 0.9797
# Epoch 7/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7705 - loss: 0.8899 - val_accuracy: 0.8636 - val_loss: 0.9489
# Epoch 8/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8279 - loss: 0.8468 - val_accuracy: 0.8636 - val_loss: 0.9212
# Epoch 9/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8443 - loss: 0.8127 - val_accuracy: 0.8636 - val_loss: 0.8957
# Epoch 10/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8525 - loss: 0.7801 - val_accuracy: 0.8636 - val_loss: 0.8712
# Epoch 11/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8607 - loss: 0.7502 - val_accuracy: 0.8636 - val_loss: 0.8440
# Epoch 12/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8689 - loss: 0.7218 - val_accuracy: 0.9545 - val_loss: 0.8158
# Epoch 13/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8770 - loss: 0.6921 - val_accuracy: 0.9545 - val_loss: 0.7863
# Epoch 14/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9016 - loss: 0.6632 - val_accuracy: 0.9545 - val_loss: 0.7565
# Epoch 15/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9098 - loss: 0.6354 - val_accuracy: 0.9545 - val_loss: 0.7256
# Epoch 16/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9098 - loss: 0.6051 - val_accuracy: 0.9545 - val_loss: 0.6942
# Epoch 17/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9180 - loss: 0.5758 - val_accuracy: 0.9545 - val_loss: 0.6621
# Epoch 18/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9098 - loss: 0.5459 - val_accuracy: 0.9545 - val_loss: 0.6309
# Epoch 19/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9180 - loss: 0.5167 - val_accuracy: 0.9545 - val_loss: 0.5965
# Epoch 20/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9180 - loss: 0.4860 - val_accuracy: 0.9545 - val_loss: 0.5634
# Epoch 21/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9344 - loss: 0.4565 - val_accuracy: 0.9545 - val_loss: 0.5286
# Epoch 22/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9344 - loss: 0.4264 - val_accuracy: 0.9545 - val_loss: 0.4955
# Epoch 23/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9344 - loss: 0.3987 - val_accuracy: 0.9545 - val_loss: 0.4637
# Epoch 24/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9426 - loss: 0.3706 - val_accuracy: 0.9545 - val_loss: 0.4333
# Epoch 25/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9508 - loss: 0.3452 - val_accuracy: 0.9545 - val_loss: 0.4026
# Epoch 26/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9590 - loss: 0.3207 - val_accuracy: 1.0000 - val_loss: 0.3740
# Epoch 27/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9590 - loss: 0.2985 - val_accuracy: 1.0000 - val_loss: 0.3481
# Epoch 28/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9672 - loss: 0.2773 - val_accuracy: 1.0000 - val_loss: 0.3236
# Epoch 29/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9672 - loss: 0.2582 - val_accuracy: 1.0000 - val_loss: 0.3012
# Epoch 30/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9672 - loss: 0.2400 - val_accuracy: 1.0000 - val_loss: 0.2813
# Epoch 31/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9672 - loss: 0.2245 - val_accuracy: 1.0000 - val_loss: 0.2623
# Epoch 32/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9672 - loss: 0.2100 - val_accuracy: 1.0000 - val_loss: 0.2457
# Epoch 33/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9672 - loss: 0.1969 - val_accuracy: 1.0000 - val_loss: 0.2306
# Epoch 34/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9672 - loss: 0.1848 - val_accuracy: 1.0000 - val_loss: 0.2172
# Epoch 35/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9672 - loss: 0.1737 - val_accuracy: 1.0000 - val_loss: 0.2052
# Epoch 36/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9672 - loss: 0.1643 - val_accuracy: 1.0000 - val_loss: 0.1950
# Epoch 37/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9754 - loss: 0.1554 - val_accuracy: 1.0000 - val_loss: 0.1862
# Epoch 38/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9754 - loss: 0.1479 - val_accuracy: 1.0000 - val_loss: 0.1780
# Epoch 39/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9754 - loss: 0.1409 - val_accuracy: 1.0000 - val_loss: 0.1705
# Epoch 40/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9754 - loss: 0.1343 - val_accuracy: 1.0000 - val_loss: 0.1632
# Epoch 41/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9754 - loss: 0.1288 - val_accuracy: 1.0000 - val_loss: 0.1573
# Epoch 42/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9754 - loss: 0.1237 - val_accuracy: 1.0000 - val_loss: 0.1523
# Epoch 43/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9754 - loss: 0.1189 - val_accuracy: 1.0000 - val_loss: 0.1472
# Epoch 44/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9754 - loss: 0.1147 - val_accuracy: 1.0000 - val_loss: 0.1424
# Epoch 45/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9754 - loss: 0.1109 - val_accuracy: 1.0000 - val_loss: 0.1388
# Epoch 46/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9754 - loss: 0.1076 - val_accuracy: 1.0000 - val_loss: 0.1353
# Epoch 47/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9754 - loss: 0.1046 - val_accuracy: 1.0000 - val_loss: 0.1316
# Epoch 48/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9754 - loss: 0.1016 - val_accuracy: 1.0000 - val_loss: 0.1286
# Epoch 49/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9754 - loss: 0.0991 - val_accuracy: 1.0000 - val_loss: 0.1259
# Epoch 50/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9754 - loss: 0.0966 - val_accuracy: 0.9545 - val_loss: 0.1237
# Epoch 51/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9754 - loss: 0.0943 - val_accuracy: 0.9545 - val_loss: 0.1213
# Epoch 52/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9754 - loss: 0.0925 - val_accuracy: 0.9545 - val_loss: 0.1189
# Epoch 53/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9754 - loss: 0.0907 - val_accuracy: 0.9545 - val_loss: 0.1174
# Epoch 54/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9754 - loss: 0.0887 - val_accuracy: 0.9545 - val_loss: 0.1154
# Epoch 55/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9836 - loss: 0.0872 - val_accuracy: 0.9545 - val_loss: 0.1143
# Epoch 56/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9836 - loss: 0.0856 - val_accuracy: 0.9545 - val_loss: 0.1129
# Epoch 57/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9836 - loss: 0.0842 - val_accuracy: 0.9545 - val_loss: 0.1116
# Epoch 58/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9836 - loss: 0.0830 - val_accuracy: 0.9545 - val_loss: 0.1095
# Epoch 59/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9836 - loss: 0.0817 - val_accuracy: 0.9545 - val_loss: 0.1081
# Epoch 60/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9836 - loss: 0.0805 - val_accuracy: 0.9545 - val_loss: 0.1073
# Epoch 61/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9836 - loss: 0.0795 - val_accuracy: 0.9545 - val_loss: 0.1065
# Epoch 62/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9836 - loss: 0.0784 - val_accuracy: 0.9545 - val_loss: 0.1058
# Epoch 63/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9836 - loss: 0.0773 - val_accuracy: 0.9545 - val_loss: 0.1045
# Epoch 64/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9836 - loss: 0.0763 - val_accuracy: 0.9545 - val_loss: 0.1038
# Epoch 65/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9836 - loss: 0.0755 - val_accuracy: 0.9545 - val_loss: 0.1032
# Epoch 66/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9836 - loss: 0.0746 - val_accuracy: 0.9545 - val_loss: 0.1027
# Epoch 67/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9836 - loss: 0.0739 - val_accuracy: 0.9545 - val_loss: 0.1017
# Epoch 68/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9836 - loss: 0.0731 - val_accuracy: 0.9545 - val_loss: 0.1013
# Epoch 69/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9836 - loss: 0.0723 - val_accuracy: 0.9545 - val_loss: 0.1007
# Epoch 70/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9836 - loss: 0.0716 - val_accuracy: 0.9545 - val_loss: 0.0998
# Epoch 71/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9836 - loss: 0.0711 - val_accuracy: 0.9545 - val_loss: 0.0993
# Epoch 72/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9836 - loss: 0.0704 - val_accuracy: 0.9545 - val_loss: 0.0980
# Epoch 73/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9836 - loss: 0.0698 - val_accuracy: 0.9545 - val_loss: 0.0980
# Epoch 74/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9836 - loss: 0.0692 - val_accuracy: 0.9545 - val_loss: 0.0975
# Epoch 75/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9836 - loss: 0.0686 - val_accuracy: 0.9545 - val_loss: 0.0965
# Epoch 76/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9836 - loss: 0.0680 - val_accuracy: 0.9545 - val_loss: 0.0970
# Epoch 77/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9836 - loss: 0.0676 - val_accuracy: 0.9545 - val_loss: 0.0963
# Epoch 78/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9836 - loss: 0.0671 - val_accuracy: 0.9545 - val_loss: 0.0971
# Epoch 79/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9836 - loss: 0.0665 - val_accuracy: 0.9545 - val_loss: 0.0968
# Epoch 80/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9836 - loss: 0.0660 - val_accuracy: 0.9545 - val_loss: 0.0958
# Epoch 81/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9836 - loss: 0.0656 - val_accuracy: 0.9545 - val_loss: 0.0953
# Epoch 82/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9836 - loss: 0.0652 - val_accuracy: 0.9545 - val_loss: 0.0939
# Epoch 83/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9836 - loss: 0.0646 - val_accuracy: 0.9545 - val_loss: 0.0935
# Epoch 84/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9836 - loss: 0.0641 - val_accuracy: 0.9545 - val_loss: 0.0933
# Epoch 85/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9836 - loss: 0.0637 - val_accuracy: 0.9545 - val_loss: 0.0931
# Epoch 86/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9836 - loss: 0.0633 - val_accuracy: 0.9545 - val_loss: 0.0931
# Epoch 87/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9836 - loss: 0.0630 - val_accuracy: 0.9545 - val_loss: 0.0926
# Epoch 88/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9836 - loss: 0.0627 - val_accuracy: 0.9545 - val_loss: 0.0932
# Epoch 89/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9836 - loss: 0.0621 - val_accuracy: 0.9545 - val_loss: 0.0928
# Epoch 90/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9836 - loss: 0.0617 - val_accuracy: 0.9545 - val_loss: 0.0925
# Epoch 91/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9836 - loss: 0.0614 - val_accuracy: 0.9545 - val_loss: 0.0924
# Epoch 92/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9836 - loss: 0.0610 - val_accuracy: 0.9545 - val_loss: 0.0915
# Epoch 93/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9836 - loss: 0.0607 - val_accuracy: 0.9545 - val_loss: 0.0907
# Epoch 94/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9836 - loss: 0.0602 - val_accuracy: 0.9545 - val_loss: 0.0913
# Epoch 95/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9836 - loss: 0.0599 - val_accuracy: 0.9545 - val_loss: 0.0915
# Epoch 96/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9836 - loss: 0.0595 - val_accuracy: 0.9545 - val_loss: 0.0915
# Epoch 97/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9836 - loss: 0.0592 - val_accuracy: 0.9545 - val_loss: 0.0914
# Epoch 98/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9836 - loss: 0.0589 - val_accuracy: 0.9545 - val_loss: 0.0921
# Epoch 99/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9836 - loss: 0.0585 - val_accuracy: 0.9545 - val_loss: 0.0920
# Epoch 100/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9836 - loss: 0.0582 - val_accuracy: 0.9545 - val_loss: 0.0913
# Epoch 101/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9836 - loss: 0.0579 - val_accuracy: 0.9545 - val_loss: 0.0905
# Epoch 102/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9836 - loss: 0.0576 - val_accuracy: 0.9545 - val_loss: 0.0903
# Epoch 103/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9836 - loss: 0.0573 - val_accuracy: 0.9545 - val_loss: 0.0897
# Epoch 104/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9836 - loss: 0.0570 - val_accuracy: 0.9545 - val_loss: 0.0901
# Epoch 105/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9836 - loss: 0.0567 - val_accuracy: 0.9545 - val_loss: 0.0888
# Epoch 106/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9836 - loss: 0.0564 - val_accuracy: 0.9545 - val_loss: 0.0892
# Epoch 107/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9836 - loss: 0.0560 - val_accuracy: 0.9545 - val_loss: 0.0886
# Epoch 108/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9836 - loss: 0.0557 - val_accuracy: 0.9545 - val_loss: 0.0880
# Epoch 109/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9836 - loss: 0.0554 - val_accuracy: 0.9545 - val_loss: 0.0875
# Epoch 110/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9836 - loss: 0.0551 - val_accuracy: 0.9545 - val_loss: 0.0876
# Epoch 111/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9836 - loss: 0.0549 - val_accuracy: 0.9545 - val_loss: 0.0878
# Epoch 112/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9836 - loss: 0.0546 - val_accuracy: 0.9545 - val_loss: 0.0873
# Epoch 113/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9836 - loss: 0.0544 - val_accuracy: 0.9545 - val_loss: 0.0863
# Epoch 114/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9836 - loss: 0.0541 - val_accuracy: 0.9545 - val_loss: 0.0859
# Epoch 115/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9836 - loss: 0.0538 - val_accuracy: 0.9545 - val_loss: 0.0872
# Epoch 116/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9836 - loss: 0.0534 - val_accuracy: 0.9545 - val_loss: 0.0869
# Epoch 117/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9836 - loss: 0.0532 - val_accuracy: 0.9545 - val_loss: 0.0866
# Epoch 118/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9836 - loss: 0.0530 - val_accuracy: 0.9545 - val_loss: 0.0863
# Epoch 119/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9836 - loss: 0.0526 - val_accuracy: 0.9545 - val_loss: 0.0872
# Epoch 120/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9836 - loss: 0.0523 - val_accuracy: 0.9545 - val_loss: 0.0871
# Epoch 121/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9836 - loss: 0.0522 - val_accuracy: 0.9545 - val_loss: 0.0863
# Epoch 122/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9836 - loss: 0.0518 - val_accuracy: 0.9545 - val_loss: 0.0869
# Epoch 123/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9836 - loss: 0.0515 - val_accuracy: 0.9545 - val_loss: 0.0871
# Epoch 124/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9836 - loss: 0.0513 - val_accuracy: 0.9545 - val_loss: 0.0865
# Epoch 125/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9836 - loss: 0.0510 - val_accuracy: 0.9545 - val_loss: 0.0868
# Epoch 126/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9836 - loss: 0.0507 - val_accuracy: 0.9545 - val_loss: 0.0865
# Epoch 127/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9836 - loss: 0.0505 - val_accuracy: 0.9545 - val_loss: 0.0862
# Epoch 128/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9836 - loss: 0.0502 - val_accuracy: 0.9545 - val_loss: 0.0862
# Epoch 129/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9836 - loss: 0.0499 - val_accuracy: 0.9545 - val_loss: 0.0863
# Epoch 130/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9836 - loss: 0.0497 - val_accuracy: 0.9545 - val_loss: 0.0861
# Epoch 131/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9836 - loss: 0.0496 - val_accuracy: 0.9545 - val_loss: 0.0852
# Epoch 132/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9836 - loss: 0.0492 - val_accuracy: 0.9545 - val_loss: 0.0849
# Epoch 133/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9836 - loss: 0.0490 - val_accuracy: 0.9545 - val_loss: 0.0859
# Epoch 134/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9836 - loss: 0.0489 - val_accuracy: 0.9545 - val_loss: 0.0868
# Epoch 135/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9836 - loss: 0.0487 - val_accuracy: 0.9545 - val_loss: 0.0871
# Epoch 136/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9836 - loss: 0.0483 - val_accuracy: 0.9545 - val_loss: 0.0855
# Epoch 137/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9836 - loss: 0.0481 - val_accuracy: 0.9545 - val_loss: 0.0845
# Epoch 138/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9836 - loss: 0.0480 - val_accuracy: 0.9545 - val_loss: 0.0841
# Epoch 139/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9836 - loss: 0.0476 - val_accuracy: 0.9545 - val_loss: 0.0842
# Epoch 140/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9836 - loss: 0.0474 - val_accuracy: 0.9545 - val_loss: 0.0837
# Epoch 141/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9836 - loss: 0.0471 - val_accuracy: 0.9545 - val_loss: 0.0841
# Epoch 142/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9836 - loss: 0.0469 - val_accuracy: 0.9545 - val_loss: 0.0848
# Epoch 143/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9836 - loss: 0.0469 - val_accuracy: 0.9545 - val_loss: 0.0856
# Epoch 144/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9836 - loss: 0.0466 - val_accuracy: 0.9545 - val_loss: 0.0857
# Epoch 145/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9836 - loss: 0.0464 - val_accuracy: 0.9545 - val_loss: 0.0859
# Epoch 146/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9836 - loss: 0.0461 - val_accuracy: 0.9545 - val_loss: 0.0862
# Epoch 147/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9836 - loss: 0.0462 - val_accuracy: 0.9545 - val_loss: 0.0869
# Epoch 148/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9836 - loss: 0.0457 - val_accuracy: 0.9545 - val_loss: 0.0853
# Epoch 149/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9836 - loss: 0.0455 - val_accuracy: 0.9545 - val_loss: 0.0848
# Epoch 150/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9836 - loss: 0.0455 - val_accuracy: 0.9545 - val_loss: 0.0836
# Epoch 151/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9836 - loss: 0.0452 - val_accuracy: 0.9545 - val_loss: 0.0839
# Epoch 152/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9836 - loss: 0.0450 - val_accuracy: 0.9545 - val_loss: 0.0834
# Epoch 153/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9836 - loss: 0.0448 - val_accuracy: 0.9545 - val_loss: 0.0832
# Epoch 154/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9836 - loss: 0.0446 - val_accuracy: 0.9545 - val_loss: 0.0833
# Epoch 155/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9836 - loss: 0.0444 - val_accuracy: 0.9545 - val_loss: 0.0833
# Epoch 156/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9836 - loss: 0.0443 - val_accuracy: 0.9545 - val_loss: 0.0834
# Epoch 157/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9836 - loss: 0.0440 - val_accuracy: 0.9545 - val_loss: 0.0832
# Epoch 158/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9836 - loss: 0.0438 - val_accuracy: 0.9545 - val_loss: 0.0836
# Epoch 159/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9836 - loss: 0.0436 - val_accuracy: 0.9545 - val_loss: 0.0838
# Epoch 160/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9836 - loss: 0.0435 - val_accuracy: 0.9545 - val_loss: 0.0838
# Epoch 161/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9836 - loss: 0.0433 - val_accuracy: 0.9545 - val_loss: 0.0837
# Epoch 162/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9836 - loss: 0.0431 - val_accuracy: 0.9545 - val_loss: 0.0838
# Epoch 163/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9836 - loss: 0.0430 - val_accuracy: 0.9545 - val_loss: 0.0840
# Epoch 164/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9836 - loss: 0.0429 - val_accuracy: 0.9545 - val_loss: 0.0826
# Epoch 165/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9836 - loss: 0.0425 - val_accuracy: 0.9545 - val_loss: 0.0827
# Epoch 166/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9836 - loss: 0.0425 - val_accuracy: 0.9545 - val_loss: 0.0840
# Epoch 167/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9836 - loss: 0.0421 - val_accuracy: 0.9545 - val_loss: 0.0835
# Epoch 168/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9836 - loss: 0.0420 - val_accuracy: 0.9545 - val_loss: 0.0837
# Epoch 169/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9836 - loss: 0.0419 - val_accuracy: 0.9545 - val_loss: 0.0838
# Epoch 170/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9836 - loss: 0.0416 - val_accuracy: 0.9545 - val_loss: 0.0832
# Epoch 171/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9836 - loss: 0.0415 - val_accuracy: 0.9545 - val_loss: 0.0826
# Epoch 172/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9836 - loss: 0.0413 - val_accuracy: 0.9545 - val_loss: 0.0813
# Epoch 173/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9836 - loss: 0.0411 - val_accuracy: 0.9545 - val_loss: 0.0806
# Epoch 174/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9836 - loss: 0.0410 - val_accuracy: 0.9545 - val_loss: 0.0807
# Epoch 175/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9836 - loss: 0.0408 - val_accuracy: 0.9545 - val_loss: 0.0805
# Epoch 176/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9836 - loss: 0.0407 - val_accuracy: 0.9545 - val_loss: 0.0806
# Epoch 177/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9836 - loss: 0.0405 - val_accuracy: 0.9545 - val_loss: 0.0804
# Epoch 178/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9836 - loss: 0.0404 - val_accuracy: 0.9545 - val_loss: 0.0799
# Epoch 179/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9836 - loss: 0.0401 - val_accuracy: 0.9545 - val_loss: 0.0799
# Epoch 180/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9836 - loss: 0.0400 - val_accuracy: 0.9545 - val_loss: 0.0808
# Epoch 181/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9836 - loss: 0.0398 - val_accuracy: 0.9545 - val_loss: 0.0811
# Epoch 182/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9836 - loss: 0.0397 - val_accuracy: 0.9545 - val_loss: 0.0814
# Epoch 183/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9836 - loss: 0.0395 - val_accuracy: 0.9545 - val_loss: 0.0804
# Epoch 184/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9836 - loss: 0.0393 - val_accuracy: 0.9545 - val_loss: 0.0798
# Epoch 185/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9836 - loss: 0.0392 - val_accuracy: 0.9545 - val_loss: 0.0798
# Epoch 186/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9836 - loss: 0.0390 - val_accuracy: 0.9545 - val_loss: 0.0790
# Epoch 187/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9836 - loss: 0.0389 - val_accuracy: 0.9545 - val_loss: 0.0789
# Epoch 188/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9836 - loss: 0.0387 - val_accuracy: 0.9545 - val_loss: 0.0791
# Epoch 189/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9836 - loss: 0.0386 - val_accuracy: 0.9545 - val_loss: 0.0790
# Epoch 190/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9836 - loss: 0.0384 - val_accuracy: 0.9545 - val_loss: 0.0775
# Epoch 191/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9836 - loss: 0.0383 - val_accuracy: 0.9545 - val_loss: 0.0772
# Epoch 192/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9836 - loss: 0.0381 - val_accuracy: 0.9545 - val_loss: 0.0774
# Epoch 193/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9836 - loss: 0.0380 - val_accuracy: 0.9545 - val_loss: 0.0770
# Epoch 194/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9836 - loss: 0.0378 - val_accuracy: 0.9545 - val_loss: 0.0776
# Epoch 195/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9836 - loss: 0.0376 - val_accuracy: 0.9545 - val_loss: 0.0786
# Epoch 196/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9836 - loss: 0.0377 - val_accuracy: 0.9545 - val_loss: 0.0795
# Epoch 197/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9836 - loss: 0.0374 - val_accuracy: 0.9545 - val_loss: 0.0780
# Epoch 198/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9836 - loss: 0.0373 - val_accuracy: 0.9545 - val_loss: 0.0784
# Epoch 199/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9836 - loss: 0.0371 - val_accuracy: 0.9545 - val_loss: 0.0781
# Epoch 200/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9836 - loss: 0.0370 - val_accuracy: 0.9545 - val_loss: 0.0764

# %%
fig, axes = plt.subplots(1, 2, figsize=(13, 4))

axes[0].plot(history.history['accuracy'],     label='Training accuracy',   linewidth=2)
axes[0].plot(history.history['val_accuracy'], label='Validation accuracy', linewidth=2, linestyle='--')
axes[0].set_title("Accuracy over epochs")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Accuracy")
axes[0].legend()
axes[0].grid(True, alpha=0.4)
axes[0].axhline(y=1/NUM_CLASSES, color='gray', linestyle=':', label='Chance level')

axes[1].plot(history.history['loss'],     label='Training loss',   linewidth=2)
axes[1].plot(history.history['val_loss'], label='Validation loss', linewidth=2, linestyle='--')
axes[1].set_title("Loss over epochs")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Loss")
axes[1].legend()
axes[1].grid(True, alpha=0.4)

plt.tight_layout()
plt.show()

# %%
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc * 100:.1f}%")
print(f"Test loss:     {test_loss:.4f}")

y_pred_nn  = np.argmax(model.predict(X_test), axis=1)
print("\n=== Neural Network Classification Report ===\n")
print(classification_report(y_test, y_pred_nn, target_names=CLASS_NAMES))

cm_nn = confusion_matrix(y_test, y_pred_nn)
disp_nn = ConfusionMatrixDisplay(cm_nn, display_labels=CLASS_NAMES)
fig, ax = plt.subplots(figsize=(6, 5))
disp_nn.plot(ax=ax, colorbar=False, cmap='Greens')
ax.set_title(f"Neural Network — Test Accuracy: {test_acc*100:.1f}%")
plt.tight_layout()
plt.show()
# Out:
# Test accuracy: 97.2%
# Test loss:     0.2515
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
#
# === Neural Network Classification Report ===
#
#               precision    recall  f1-score   support
#
#        squat       1.00      0.92      0.96        12
#        lunge       1.00      1.00      1.00        12
#         jump       0.92      1.00      0.96        12
#
#     accuracy                           0.97        36
#    macro avg       0.97      0.97      0.97        36
# weighted avg       0.97      0.97      0.97        36

# %%
from pathlib import Path

# Keep all generated deployment artifacts together.
MODEL_DIR = Path("./model")
MODEL_DIR.mkdir(parents=True, exist_ok=True)

converter    = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

model_size_bytes = len(tflite_model)
print(f"TFLite model size: {model_size_bytes} bytes ({model_size_bytes / 1024:.1f} KB)")
print(f"For reference — Nano 33 BLE Sense Flash: 1024 KB, RAM: 256 KB")

# Save the converted model under week-4/model/.
model_path = MODEL_DIR / "ORBIT_gesture_model.tflite"
model_path.write_bytes(tflite_model)

print(f"Saved: {model_path.resolve()}")
# Out:
# INFO:tensorflow:Assets written to: C:\Users\allis\AppData\Local\Temp\tmp77cdj24e\assets
# INFO:tensorflow:Assets written to: C:\Users\allis\AppData\Local\Temp\tmp77cdj24e\assets
# Saved artifact at 'C:\Users\allis\AppData\Local\Temp\tmp77cdj24e'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 4), dtype=tf.float32, name='keras_tensor_4')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   1818683219232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1818703219696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1818703222336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1818703220928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1818703216704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1818703223568: TensorSpec(shape=(), dtype=tf.resource, name=None)
# TFLite model size: 3312 bytes (3.2 KB)
# For reference — Nano 33 BLE Sense Flash: 1024 KB, RAM: 256 KB
# Saved: C:\Users\allis\Documents\agentic-mote-python\week-4\model\ORBIT_gesture_model.tflite

# %%
saved_model_exists = model_path.exists()
saved_model_size   = model_path.stat().st_size if saved_model_exists else 0

print(f"Model directory: {MODEL_DIR.resolve()}")
print(f"Model file exists: {saved_model_exists}")
print(f"Saved file size: {saved_model_size} bytes ({saved_model_size / 1024:.1f} KB)")
print(f"Size matches converted model: {saved_model_size == model_size_bytes}")
# Out:
# Model directory: C:\Users\allis\Documents\agentic-mote-python\week-4\model
# Model file exists: True
# Saved file size: 3312 bytes (3.2 KB)
# Size matches converted model: True

# %%
# LiteRT is the modern replacement for the deprecated tf.lite.Interpreter API.
from ai_edge_litert.interpreter import Interpreter

# Load the exact model artifact saved in Section 5.2.
saved_tflite_model = model_path.read_bytes()
interpreter = Interpreter(model_path=str(model_path))

# Reserve the memory required by the model's tensors.
interpreter.allocate_tensors()

# Tensor details include each tensor's index, shape, and data type.
input_details  = interpreter.get_input_details()
output_details = interpreter.get_output_details()

y_pred_tflite = []
for sample in X_test:
    # The model expects one row containing 24 normalized features.
    # reshape(1, -1) adds the batch dimension: (24,) becomes (1, 24).
    input_tensor = sample.reshape(1, -1).astype(np.float32)

    # Copy this test window into the model's input tensor.
    interpreter.set_tensor(input_details[0]['index'],
                           input_tensor)

    # Run one forward pass through the converted neural network.
    interpreter.invoke()

    # Read the three output probabilities and keep the winning class index.
    output = interpreter.get_tensor(output_details[0]['index'])
    y_pred_tflite.append(np.argmax(output))

y_pred_tflite = np.array(y_pred_tflite)
tflite_acc    = np.mean(y_pred_tflite == y_test)

print(f"Original Keras model test accuracy: {test_acc * 100:.1f}%")
print(f"TFLite model test accuracy:         {tflite_acc * 100:.1f}%")
print(f"All predictions identical:          {np.all(y_pred_tflite == y_pred_nn)}")
# Out:
# Original Keras model test accuracy: 97.2%
# TFLite model test accuracy:         97.2%
# All predictions identical:          True

# %%
def tflite_to_c_header(tflite_bytes, array_name='model_data', output_file=MODEL_DIR / 'ORBIT_model.h'):
    """Convert a .tflite binary into a C header with a byte array."""
    hex_values = ', '.join([f'0x{b:02x}' for b in tflite_bytes])
    header_content = f"""// Auto-generated by Week 4 AI/ML Mote Lab — do not edit manually.
// Re-run the Python conversion cell if you retrain the model.

#pragma once

const unsigned char {array_name}[] = {{
  {hex_values}
}};

const int {array_name}_len = {len(tflite_bytes)};
"""
    with open(output_file, 'w') as f:
        f.write(header_content)
    print(f"Generated: {output_file.resolve()}  ({len(tflite_bytes)} bytes)")

tflite_to_c_header(saved_tflite_model)
# Out:
# Generated: C:\Users\allis\Documents\agentic-mote-python\week-4\model\ORBIT_model.h  (3312 bytes)

# %%
def scaler_to_c_header(scaler, num_features, output_file=MODEL_DIR / 'ORBIT_normalizer.h'):
    """Generate a C header with StandardScaler mean and std parameters."""
    means = ', '.join([f'{v:.8f}f' for v in scaler.mean_])
    stds  = ', '.join([f'{v:.8f}f' for v in scaler.scale_])
    header_content = f"""// Auto-generated by Week 4 AI/ML Mote Lab — do not edit manually.
// These normalization parameters must exactly match the Python StandardScaler used during training.
// If you retrain with new data, regenerate this file.

#pragma once

const int   NUM_FEATURES        = {num_features};
const float FEATURE_MEAN[{num_features}] = {{ {means} }};
const float FEATURE_STD[{num_features}]  = {{ {stds} }};
"""
    with open(output_file, 'w') as f:
        f.write(header_content)
    print(f"Generated: {output_file.resolve()}")

scaler_to_c_header(scaler, NUM_FEATURES)
# Out:
# Generated: C:\Users\allis\Documents\agentic-mote-python\week-4\model\ORBIT_normalizer.h
